# %%
final_df.head()
final_df.shape
# Out:
# (89316, 13)

# %%
final_df["total_order_value"] = final_df["price"] + final_df["shipping_charges"]

final_df.to_csv("final_ecommerce_dashboard_data_clean.csv", index=False)

# %%
final_df = merged_df.groupby("order_id").agg({
    "customer_id": "first",
    "order_status": "first",
    "customer_city": "first",
    "customer_state": "first",
    "price": "sum",
    "shipping_charges": "sum",
    "payment_value": "sum",
    "product_category_name": "first",
    "product_weight_g": "mean",
    "purchase_year": "first",
    "purchase_month": "first"
}).reset_index()

# %%
merged_df[["order_purchase_timestamp", "purchase_year", "purchase_month"]].head()
# Out:
#   order_purchase_timestamp  purchase_year  purchase_month
# 0      2017-10-22 18:57:54           2017              10
# 1      2017-10-22 18:57:54           2017              10
# 2      2017-10-22 18:57:54           2017              10
# 3      2017-10-22 18:57:54           2017              10
# 4      2017-10-22 18:57:54           2017              10

# %%
merged_df["order_purchase_timestamp"] = pd.to_datetime(
    merged_df["order_purchase_timestamp"],
    errors="coerce"
)

merged_df["purchase_year"] = merged_df["order_purchase_timestamp"].dt.year
merged_df["purchase_month"] = merged_df["order_purchase_timestamp"].dt.month

# %%
final_df = merged_df.groupby("order_id").agg({
    "customer_id":"first",
    "order_status":"first",
    "customer_city":"first",
    "customer_state":"first",
    "price":"sum",
    "shipping_charges":"sum",
    "payment_value":"sum",
    "product_category_name":"first",
    "product_weight_g":"mean",
    "purchase_year":"first",
    "purchase_month":"first"
}).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 final_df = merged_df.groupby("order_id").agg({
#       2     "customer_id":"first",
#       3     "order_status":"first",
#       4     "customer_city":"first",
#
# File d:\Portfolio\.venv\Lib\site-packages\pandas\core\groupby\generic.py:2291, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    2288     kwargs["engine_kwargs"] = engine_kwargs
#    2290 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 2291 result = op.agg()
#    2292 if not is_dict_like(func) and result is not None:
#    2293     # GH #52849
#    2294     if not self.as_index and is_list_like(func):
#
# File d:\Portfolio\.venv\Lib\site-packages\pandas\core\apply.py:294, in Apply.agg(self)
#     291     return self.apply_str()
#     293 if is_dict_like(func):
# ...

# %%
len(merged_df)
# Out:
# 2529486

# %%
merged_df["order_id"].nunique()
# Out:
# 89316

# %%
merged_df["order_id"].duplicated().sum()
# Out:
# np.int64(2440170)

# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("train/df_Customers.csv")
orders = pd.read_csv("train/df_Orders.csv")
order_items = pd.read_csv("train/df_OrderItems.csv")
payments = pd.read_csv("train/df_Payments.csv")
products = pd.read_csv("train/df_Products.csv")

# %%
merged_df = orders.merge(customers, on="customer_id", how="left")
merged_df = merged_df.merge(order_items, on="order_id", how="left")
merged_df = merged_df.merge(payments, on="order_id", how="left")
merged_df = merged_df.merge(products, on="product_id", how="left")

# %%
merged_df.to_csv("final_ecommerce_dashboard_data.csv", index=False)
